# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers

# %%
df = pd.read_csv('./AirbnbData/CleanData/df_modelo_limpio.csv')
df = df.drop(columns = (['Unnamed: 0', 'id', 'neighbourhood_group_cleansed', 'property_type']))
df
# Out:
#        host_is_superhost  host_identity_verified neighbourhood_cleansed  \
# 0                      1                       1         Hispanoamérica
# 1                      0                       1               Cármenes
# 2                      0                       1                Legazpi
# 3                      0                       0                    Sol
# 4                      0                       0            Embajadores
# ...                  ...                     ...                    ...
# 11785                  0                       1            Castillejos
# 11786                  0                       0                    Sol
# 11787                  0                       0               Almenara
# 11788                  0                       1               Justicia
# 11789                  0                       0                 Ventas
#
#              room_type  bedrooms  beds  price  number_of_reviews bathrooms  \
# 0         Private room       1.0   1.0   60.0                 78       1.0
# 1         Private room       1.0   1.0   31.0                 33       1.0
# 2         Private room       1.0   1.0   26.0                149       1.0
# 3      Entire home/apt       1.0   2.0   65.0                170       1.0
# 4      Entire home/apt       1.0   1.0   54.0                  8       1.0
# ...                ...       ...   ...    ...                ...       ...
# 11785  Entire home/apt       3.0   4.0   62.0                  1       1.5
# 11786     Private room       1.0   2.0   60.0                  2       1.0
# 11787     Private room       1.0   1.0   25.0                  1       1.0
# 11788  Entire home/apt       1.0   1.0   44.0                  1       1.0
# 11789  Entire home/apt       2.0   2.0   70.0                  1       2.0
#
#        puntuacion_media
# 0              4.583333
# 1              4.653846
# 2              4.612613
# 3              4.596774
# 4              4.571429
# ...                 ...
# 11785          5.000000
# 11786          4.500000
# 11787          5.000000
# 11788          5.000000
# 11789          5.000000
#
# [11790 rows x 10 columns]

# %%
df['bathrooms'] = df['bathrooms'].apply(lambda x: float(x))

# %%
df.dtypes
# Out:
# host_is_superhost           int64
# host_identity_verified      int64
# neighbourhood_cleansed     object
# room_type                  object
# bedrooms                  float64
# beds                      float64
# price                     float64
# number_of_reviews           int64
# bathrooms                 float64
# puntuacion_media          float64
# dtype: object

# %% [markdown]
# ### Datos

# %%
X = df.drop(columns = (['price']))

# %%
labelencoder = LabelEncoder()

X['host_is_superhost'] = labelencoder.fit_transform(X['host_is_superhost'])
X['host_identity_verified'] = labelencoder.fit_transform(X['host_identity_verified'])
X['neighbourhood_cleansed'] = labelencoder.fit_transform(X['neighbourhood_cleansed'])
X['room_type'] = labelencoder.fit_transform(X['room_type'])

# %%
CONTINUAL_COLUMNS = ['bedrooms', 'beds', 'number_of_reviews', 'bathrooms', 'puntuacion_media']

# %%
df[CONTINUAL_COLUMNS]=(df[CONTINUAL_COLUMNS]-df[CONTINUAL_COLUMNS].mean())/df[CONTINUAL_COLUMNS].std()

# %%
plt.hist(df['price'], bins = 7)
# Out:
# (array([5384., 3701., 1506.,  617.,  316.,  147.,  119.]),
#  array([  9.        ,  50.57142857,  92.14285714, 133.71428571,
#         175.28571429, 216.85714286, 258.42857143, 300.        ]),
#  <BarContainer object of 7 artists>)

# %%
def assign_class(price):
    classif = 13 #si algun caso devuelve un 13 -> error
    if (price <= 40):
        classif = 0
    elif (40 < price <= 85):
        classif = 1
    elif (85 < price <= 150):
        classif = 2
    elif (150 < price <= 300):
        classif = 3
        
    return classif

# %%
df['price'] = df['price'].apply(lambda x: assign_class(x))

# %%
df['price'].value_counts()
# Out:
# 1    4569
# 0    4117
# 2    2245
# 3     859
# Name: price, dtype: int64

# %%
y = df['price']

# %% [markdown]
# ### Modelo

# %%
input_num = tf.keras.layers.Input(shape = (5,), name = "num_input")
input_cat1 = tf.keras.layers.Input(shape = (1,), name = "superhost")
input_cat2 = tf.keras.layers.Input(shape = (1,), name = "identity")
input_cat3 = tf.keras.layers.Input(shape = (1,), name = "neighbourhood")
input_cat4 = tf.keras.layers.Input(shape = (1,), name = "room")

x_numeric = tf.keras.layers.Dense(128, name = "encoding_num")(input_num)
x_categoric1 = tf.keras.layers.Embedding(input_dim = 2, output_dim = 3, name = "embedding_cat1")(input_cat1)
x_categoric1 = tf.keras.layers.Reshape(target_shape = (3,), name = "flat_vec1")(x_categoric1)
x_categoric2 = tf.keras.layers.Embedding(input_dim = 2, output_dim = 3, name = "embedding_cat2")(input_cat2)
x_categoric2 = tf.keras.layers.Reshape(target_shape = (3,), name = "flat_vec2")(x_categoric2)
x_categoric3 = tf.keras.layers.Embedding(input_dim = 126, output_dim = 3, name = "embedding_cat3")(input_cat3)
x_categoric3 = tf.keras.layers.Reshape(target_shape = (3,), name = "flat_vec3")(x_categoric3)
x_categoric4 = tf.keras.layers.Embedding(input_dim = 4, output_dim = 3, name = "embedding_cat4")(input_cat4)
x_categoric4 = tf.keras.layers.Reshape(target_shape = (3,), name = "flat_vec4")(x_categoric4)

x_all = tf.keras.layers.Concatenate()([x_numeric, x_categoric1,x_categoric2,x_categoric3,x_categoric4])
x_all = tf.keras.layers.Dense(512, name = "hidden_layer_1", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(256, name = "hidden_layer_3", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(256, name = "hidden_layer_4", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(128, name = "hidden_layer_5", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(64, name = "hidden_layer_6", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(64, name = "hidden_layer_7", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(32, name = "hidden_layer_8", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(4, name = "final_layer", activation = "softmax")(x_all)
model_in = tf.keras.models.Model([input_num, input_cat1, input_cat2, input_cat3, input_cat4], x_all, name = "funct_model_all")

# %%
print(model_in.summary())
# Out:
# Model: "funct_model_all"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  superhost (InputLayer)         [(None, 1)]          0           []
#
#  identity (InputLayer)          [(None, 1)]          0           []
#
#  neighbourhood (InputLayer)     [(None, 1)]          0           []
#
#  room (InputLayer)              [(None, 1)]          0           []
#
#  num_input (InputLayer)         [(None, 5)]          0           []
#
#  embedding_cat1 (Embedding)     (None, 1, 3)         6           ['superhost[0][0]']
#
#  embedding_cat2 (Embedding)     (None, 1, 3)         6           ['identity[0][0]']
#
#  embedding_cat3 (Embedding)     (None, 1, 3)         378         ['neighbourhood[0][0]']
#
#  embedding_cat4 (Embedding)     (None, 1, 3)         12          ['room[0][0]']
#
#  encoding_num (Dense)           (None, 128)          768         ['num_input[0][0]']
#
#  flat_vec1 (Reshape)            (None, 3)            0           ['embedding_cat1[0][0]']
#
#  flat_vec2 (Reshape)            (None, 3)            0           ['embedding_cat2[0][0]']
#
#  flat_vec3 (Reshape)            (None, 3)            0           ['embedding_cat3[0][0]']
#
#  flat_vec4 (Reshape)            (None, 3)            0           ['embedding_cat4[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 140)          0           ['encoding_num[0][0]',
#                                                                   'flat_vec1[0][0]',
#                                                                   'flat_vec2[0][0]',
#                                                                   'flat_vec3[0][0]',
#                                                                   'flat_vec4[0][0]']
#
#  hidden_layer_1 (Dense)         (None, 512)          72192       ['concatenate_7[0][0]']
#
#  dropout_51 (Dropout)           (None, 512)          0           ['hidden_layer_1[0][0]']
#
#  hidden_layer_3 (Dense)         (None, 256)          131328      ['dropout_51[0][0]']
#
#  dropout_52 (Dropout)           (None, 256)          0           ['hidden_layer_3[0][0]']
#
#  hidden_layer_4 (Dense)         (None, 256)          65792       ['dropout_52[0][0]']
#
#  dropout_53 (Dropout)           (None, 256)          0           ['hidden_layer_4[0][0]']
#
#  hidden_layer_5 (Dense)         (None, 128)          32896       ['dropout_53[0][0]']
#
#  dropout_54 (Dropout)           (None, 128)          0           ['hidden_layer_5[0][0]']
#
#  hidden_layer_6 (Dense)         (None, 64)           8256        ['dropout_54[0][0]']
#
#  dropout_55 (Dropout)           (None, 64)           0           ['hidden_layer_6[0][0]']
#
#  hidden_layer_7 (Dense)         (None, 64)           4160        ['dropout_55[0][0]']
#
#  dropout_56 (Dropout)           (None, 64)           0           ['hidden_layer_7[0][0]']
#
#  hidden_layer_8 (Dense)         (None, 32)           2080        ['dropout_56[0][0]']
#
#  dropout_57 (Dropout)           (None, 32)           0           ['hidden_layer_8[0][0]']
#
#  final_layer (Dense)            (None, 4)            132         ['dropout_57[0][0]']
#
# ==================================================================================================
# Total params: 318,006
# Trainable params: 318,006
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model_in.compile("adam", "sparse_categorical_crossentropy", metrics = ["accuracy"])

# %%
history = model_in.fit((X[CONTINUAL_COLUMNS], X['host_is_superhost'], X['host_identity_verified'], X['neighbourhood_cleansed'], X['room_type']), 
                              y, batch_size = 64, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 148/148 [==============================] - 4s 19ms/step - loss: nan - accuracy: 0.3379 - val_loss: nan - val_accuracy: 0.3842
# Epoch 2/100
# 148/148 [==============================] - 3s 19ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 3/100
# 148/148 [==============================] - 3s 19ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 4/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 5/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 6/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 7/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 8/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 9/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 10/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 11/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 12/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 13/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 14/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 15/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 16/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 17/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 18/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 19/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 20/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 21/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 22/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 23/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 24/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 25/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 26/100
# 148/148 [==============================] - 3s 18ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 27/100
# 148/148 [==============================] - 3s 18ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 28/100
# 148/148 [==============================] - 3s 18ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 29/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 30/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 31/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 32/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 33/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 34/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 35/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 36/100
# 148/148 [==============================] - 3s 19ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 37/100
# 148/148 [==============================] - 3s 19ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 38/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 39/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 40/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 41/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 42/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 43/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 44/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 45/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 46/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 47/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 48/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 49/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 50/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 51/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 52/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 53/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 54/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 55/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 56/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 57/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 58/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 59/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 60/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 61/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 62/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 63/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 64/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 65/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 66/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 67/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 68/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 69/100
# 148/148 [==============================] - 3s 18ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 70/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 71/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 72/100
# 148/148 [==============================] - 3s 18ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 73/100
# 148/148 [==============================] - 4s 24ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 74/100
# 148/148 [==============================] - 4s 24ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 75/100
# 148/148 [==============================] - 3s 18ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 76/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 77/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 78/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 79/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 80/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 81/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 82/100
# 148/148 [==============================] - 3s 18ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 83/100
# 148/148 [==============================] - 3s 20ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 84/100
# 148/148 [==============================] - 3s 21ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 85/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 86/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 87/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 88/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 89/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 90/100
# 148/148 [==============================] - 2s 16ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 91/100
# 148/148 [==============================] - 2s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 92/100
# 148/148 [==============================] - 3s 18ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 93/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 94/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 95/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 96/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 97/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 98/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 99/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
# Epoch 100/100
# 148/148 [==============================] - 3s 17ms/step - loss: nan - accuracy: 0.3404 - val_loss: nan - val_accuracy: 0.3842
