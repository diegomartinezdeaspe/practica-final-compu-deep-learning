# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers

# %%
df = pd.read_csv('../AirbnbData/CleanData/df_modelo_limpio.csv')
df = df.drop(columns = (['Unnamed: 0', 'id', 'neighbourhood_group_cleansed', 'property_type']))
df
# Out:
#        host_is_superhost  host_identity_verified neighbourhood_cleansed  \
# 0                      1                       1         Hispanoamérica
# 1                      0                       1               Cármenes
# 2                      0                       1                Legazpi
# 3                      0                       0                    Sol
# 4                      0                       0            Embajadores
# ...                  ...                     ...                    ...
# 11535                  0                       1            Castillejos
# 11536                  0                       0                    Sol
# 11537                  0                       0               Almenara
# 11538                  0                       1               Justicia
# 11539                  0                       0                 Ventas
#
#              room_type  bedrooms  beds  price  availability_365  \
# 0         Private room       1.0   1.0   60.0               180
# 1         Private room       1.0   1.0   31.0               364
# 2         Private room       1.0   1.0   26.0               365
# 3      Entire home/apt       1.0   2.0   65.0               351
# 4      Entire home/apt       1.0   1.0   54.0                 0
# ...                ...       ...   ...    ...               ...
# 11535  Entire home/apt       3.0   4.0   62.0               360
# 11536     Private room       1.0   2.0   60.0               158
# 11537     Private room       1.0   1.0   25.0               175
# 11538  Entire home/apt       1.0   1.0   44.0               331
# 11539  Entire home/apt       2.0   2.0   70.0                89
#
#        number_of_reviews  calculated_host_listings_count  reviews_per_month  \
# 0                     78                               1               0.58
# 1                     33                               2               0.42
# 2                    149                               1               1.12
# 3                    170                               3               1.29
# 4                      8                               1               0.11
# ...                  ...                             ...                ...
# 11535                  1                              38               1.00
# 11536                  2                               6               2.00
# 11537                  1                               1               1.00
# 11538                  1                               2               1.00
# 11539                  1                               1               1.00
#
#       bathrooms  puntuacion_media
# 0           1.0          4.583333
# 1           1.0          4.653846
# 2           1.0          4.612613
# 3           1.0          4.596774
# 4           1.0          4.571429
# ...         ...               ...
# 11535       1.5          5.000000
# 11536       1.0          4.500000
# 11537       1.0          5.000000
# 11538       1.0          5.000000
# 11539       2.0          5.000000
#
# [11540 rows x 13 columns]

# %%
df['bathrooms'] = df['bathrooms'].apply(lambda x: float(x))
df = df.dropna()

# %%
df.dtypes
# Out:
# host_is_superhost                   int64
# host_identity_verified              int64
# neighbourhood_cleansed             object
# room_type                          object
# bedrooms                          float64
# beds                              float64
# price                             float64
# availability_365                    int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# reviews_per_month                 float64
# bathrooms                         float64
# puntuacion_media                  float64
# dtype: object

# %% [markdown]
# ### Datos

# %%
X = df.drop(columns = (['price']))

# %%
labelencoder = LabelEncoder()

X['host_is_superhost'] = labelencoder.fit_transform(X['host_is_superhost'])
X['host_identity_verified'] = labelencoder.fit_transform(X['host_identity_verified'])
X['neighbourhood_cleansed'] = labelencoder.fit_transform(X['neighbourhood_cleansed'])
X['room_type'] = labelencoder.fit_transform(X['room_type'])

# %%
CONTINUAL_COLUMNS = ['bedrooms', 'beds', 'number_of_reviews', 'bathrooms', 'puntuacion_media']

# %%
df[CONTINUAL_COLUMNS]=(df[CONTINUAL_COLUMNS]-df[CONTINUAL_COLUMNS].mean())/df[CONTINUAL_COLUMNS].std()
# Out:
# C:\Users\jaime\anaconda3\envs\swa-dev\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
plt.hist(df['price'], bins = 7)
# Out:
# (array([3794., 3503., 2135., 1050.,  527.,  312.,  202.]),
#  array([  9.        ,  39.14285714,  69.28571429,  99.42857143,
#         129.57142857, 159.71428571, 189.85714286, 220.        ]),
#  <BarContainer object of 7 artists>)

# %%
def assign_class(price):
    classif = 13 #si algun caso devuelve un 13 -> error
    if (price <= 35):
        classif = 0
    elif (35 < price <= 60):
        classif = 1
    elif (60 < price <= 90):
        classif = 2
    elif (90 < price <= 140):
        classif = 3
    elif (140 < price <= 300):
        classif = 4
        
    return classif

# %%
df['price'] = df['price'].apply(lambda x: assign_class(x))
# Out:
# C:\Users\jaime\AppData\Local\Temp\ipykernel_21304\2772249497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].apply(lambda x: assign_class(x))

# %%
df['price'].value_counts()
# Out:
# 0    3338
# 1    3216
# 2    2447
# 3    1706
# 4     816
# Name: price, dtype: int64

# %%
y = df['price']

# %% [markdown]
# ### Modelo

# %%
input_num = tf.keras.layers.Input(shape = (5,), name = "num_input")
input_cat1 = tf.keras.layers.Input(shape = (1,), name = "superhost")
input_cat2 = tf.keras.layers.Input(shape = (1,), name = "identity")
input_cat3 = tf.keras.layers.Input(shape = (1,), name = "neighbourhood")
input_cat4 = tf.keras.layers.Input(shape = (1,), name = "room")

x_numeric = tf.keras.layers.Dense(128, name = "encoding_num")(input_num)
x_categoric1 = tf.keras.layers.Embedding(input_dim = 2, output_dim = 3, name = "embedding_cat1")(input_cat1)
x_categoric1 = tf.keras.layers.Reshape(target_shape = (3,), name = "flat_vec1")(x_categoric1)
x_categoric2 = tf.keras.layers.Embedding(input_dim = 2, output_dim = 3, name = "embedding_cat2")(input_cat2)
x_categoric2 = tf.keras.layers.Reshape(target_shape = (3,), name = "flat_vec2")(x_categoric2)
x_categoric3 = tf.keras.layers.Embedding(input_dim = 126, output_dim = 3, name = "embedding_cat3")(input_cat3)
x_categoric3 = tf.keras.layers.Reshape(target_shape = (3,), name = "flat_vec3")(x_categoric3)
x_categoric4 = tf.keras.layers.Embedding(input_dim = 4, output_dim = 3, name = "embedding_cat4")(input_cat4)
x_categoric4 = tf.keras.layers.Reshape(target_shape = (3,), name = "flat_vec4")(x_categoric4)

x_all = tf.keras.layers.Concatenate()([x_numeric, x_categoric1,x_categoric2,x_categoric3,x_categoric4])
x_all = tf.keras.layers.Dense(512, name = "hidden_layer_1", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(256, name = "hidden_layer_3", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(256, name = "hidden_layer_4", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(128, name = "hidden_layer_5", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(64, name = "hidden_layer_6", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(64, name = "hidden_layer_7", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(32, name = "hidden_layer_8", activation="relu", kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4))(x_all)
x_all = tf.keras.layers.Dropout(rate=0.2)(x_all)
x_all = tf.keras.layers.Dense(5, name = "final_layer", activation = "softmax")(x_all)
model_in = tf.keras.models.Model([input_num, input_cat1, input_cat2, input_cat3, input_cat4], x_all, name = "funct_model_all")

# %%
print(model_in.summary())
# Out:
# Model: "funct_model_all"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  superhost (InputLayer)         [(None, 1)]          0           []
#
#  identity (InputLayer)          [(None, 1)]          0           []
#
#  neighbourhood (InputLayer)     [(None, 1)]          0           []
#
#  room (InputLayer)              [(None, 1)]          0           []
#
#  num_input (InputLayer)         [(None, 5)]          0           []
#
#  embedding_cat1 (Embedding)     (None, 1, 3)         6           ['superhost[0][0]']
#
#  embedding_cat2 (Embedding)     (None, 1, 3)         6           ['identity[0][0]']
#
#  embedding_cat3 (Embedding)     (None, 1, 3)         378         ['neighbourhood[0][0]']
#
#  embedding_cat4 (Embedding)     (None, 1, 3)         12          ['room[0][0]']
#
#  encoding_num (Dense)           (None, 128)          768         ['num_input[0][0]']
#
#  flat_vec1 (Reshape)            (None, 3)            0           ['embedding_cat1[0][0]']
#
#  flat_vec2 (Reshape)            (None, 3)            0           ['embedding_cat2[0][0]']
#
#  flat_vec3 (Reshape)            (None, 3)            0           ['embedding_cat3[0][0]']
#
#  flat_vec4 (Reshape)            (None, 3)            0           ['embedding_cat4[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 140)          0           ['encoding_num[0][0]',
#                                                                   'flat_vec1[0][0]',
#                                                                   'flat_vec2[0][0]',
#                                                                   'flat_vec3[0][0]',
#                                                                   'flat_vec4[0][0]']
#
#  hidden_layer_1 (Dense)         (None, 512)          72192       ['concatenate_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 512)          0           ['hidden_layer_1[0][0]']
#
#  hidden_layer_3 (Dense)         (None, 256)          131328      ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 256)          0           ['hidden_layer_3[0][0]']
#
#  hidden_layer_4 (Dense)         (None, 256)          65792       ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)            (None, 256)          0           ['hidden_layer_4[0][0]']
#
#  hidden_layer_5 (Dense)         (None, 128)          32896       ['dropout_9[0][0]']
#
#  dropout_10 (Dropout)           (None, 128)          0           ['hidden_layer_5[0][0]']
#
#  hidden_layer_6 (Dense)         (None, 64)           8256        ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 64)           0           ['hidden_layer_6[0][0]']
#
#  hidden_layer_7 (Dense)         (None, 64)           4160        ['dropout_11[0][0]']
#
#  dropout_12 (Dropout)           (None, 64)           0           ['hidden_layer_7[0][0]']
#
#  hidden_layer_8 (Dense)         (None, 32)           2080        ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)           (None, 32)           0           ['hidden_layer_8[0][0]']
#
#  final_layer (Dense)            (None, 5)            165         ['dropout_13[0][0]']
#
# ==================================================================================================
# Total params: 318,039
# Trainable params: 318,039
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model_in.compile("adam", "sparse_categorical_crossentropy", metrics = ["accuracy"])

# %%
history = model_in.fit((X[CONTINUAL_COLUMNS], X['host_is_superhost'], X['host_identity_verified'], X['neighbourhood_cleansed'], X['room_type']), 
                              y, batch_size = 64, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 145/145 [==============================] - 5s 20ms/step - loss: 1.8535 - accuracy: 0.2683 - val_loss: 1.6837 - val_accuracy: 0.3306
# Epoch 2/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.6973 - accuracy: 0.3011 - val_loss: 1.5555 - val_accuracy: 0.4616
# Epoch 3/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.6007 - accuracy: 0.3744 - val_loss: 1.5187 - val_accuracy: 0.4304
# Epoch 4/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.5350 - accuracy: 0.4044 - val_loss: 1.4225 - val_accuracy: 0.4443
# Epoch 5/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.4850 - accuracy: 0.4270 - val_loss: 1.4177 - val_accuracy: 0.4568
# Epoch 6/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.4328 - accuracy: 0.4451 - val_loss: 1.3876 - val_accuracy: 0.4625
# Epoch 7/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.4207 - accuracy: 0.4506 - val_loss: 1.3494 - val_accuracy: 0.4612
# Epoch 8/100
# 145/145 [==============================] - 3s 24ms/step - loss: 1.3610 - accuracy: 0.4666 - val_loss: 1.3424 - val_accuracy: 0.4685
# Epoch 9/100
# 145/145 [==============================] - 4s 24ms/step - loss: 1.3355 - accuracy: 0.4786 - val_loss: 1.3055 - val_accuracy: 0.4738
# Epoch 10/100
# 145/145 [==============================] - 3s 22ms/step - loss: 1.3200 - accuracy: 0.4860 - val_loss: 1.3267 - val_accuracy: 0.4915
# Epoch 11/100
# 145/145 [==============================] - 3s 20ms/step - loss: 1.3105 - accuracy: 0.4864 - val_loss: 1.3151 - val_accuracy: 0.4937
# Epoch 12/100
# 145/145 [==============================] - 3s 19ms/step - loss: 1.2891 - accuracy: 0.4935 - val_loss: 1.3157 - val_accuracy: 0.5024
# Epoch 13/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.2753 - accuracy: 0.4984 - val_loss: 1.2887 - val_accuracy: 0.4985
# Epoch 14/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.2626 - accuracy: 0.4988 - val_loss: 1.2613 - val_accuracy: 0.5089
# Epoch 15/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.2521 - accuracy: 0.4985 - val_loss: 1.2659 - val_accuracy: 0.5020
# Epoch 16/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.2427 - accuracy: 0.5029 - val_loss: 1.3288 - val_accuracy: 0.4685
# Epoch 17/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.2336 - accuracy: 0.5105 - val_loss: 1.2340 - val_accuracy: 0.5124
# Epoch 18/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.2213 - accuracy: 0.5089 - val_loss: 1.2407 - val_accuracy: 0.5063
# Epoch 19/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.2340 - accuracy: 0.4998 - val_loss: 1.3375 - val_accuracy: 0.4698
# Epoch 20/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.2098 - accuracy: 0.5111 - val_loss: 1.2362 - val_accuracy: 0.5063
# Epoch 21/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.2141 - accuracy: 0.5125 - val_loss: 1.2181 - val_accuracy: 0.5041
# Epoch 22/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1995 - accuracy: 0.5135 - val_loss: 1.2554 - val_accuracy: 0.4863
# Epoch 23/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1937 - accuracy: 0.5181 - val_loss: 1.2113 - val_accuracy: 0.5141
# Epoch 24/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1849 - accuracy: 0.5204 - val_loss: 1.2080 - val_accuracy: 0.5137
# Epoch 25/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1840 - accuracy: 0.5112 - val_loss: 1.2634 - val_accuracy: 0.4915
# Epoch 26/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1739 - accuracy: 0.5108 - val_loss: 1.2102 - val_accuracy: 0.4976
# Epoch 27/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1781 - accuracy: 0.5139 - val_loss: 1.2373 - val_accuracy: 0.4911
# Epoch 28/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1732 - accuracy: 0.5178 - val_loss: 1.2713 - val_accuracy: 0.4725
# Epoch 29/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1725 - accuracy: 0.5145 - val_loss: 1.2433 - val_accuracy: 0.4907
# Epoch 30/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1580 - accuracy: 0.5206 - val_loss: 1.2230 - val_accuracy: 0.4993
# Epoch 31/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1535 - accuracy: 0.5161 - val_loss: 1.2040 - val_accuracy: 0.5011
# Epoch 32/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1547 - accuracy: 0.5239 - val_loss: 1.2299 - val_accuracy: 0.4902
# Epoch 33/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1493 - accuracy: 0.5178 - val_loss: 1.1826 - val_accuracy: 0.5137
# Epoch 34/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1489 - accuracy: 0.5199 - val_loss: 1.2581 - val_accuracy: 0.4590
# Epoch 35/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1494 - accuracy: 0.5221 - val_loss: 1.2412 - val_accuracy: 0.4868
# Epoch 36/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1425 - accuracy: 0.5257 - val_loss: 1.1730 - val_accuracy: 0.5028
# Epoch 37/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1419 - accuracy: 0.5243 - val_loss: 1.1854 - val_accuracy: 0.5154
# Epoch 38/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1422 - accuracy: 0.5202 - val_loss: 1.1896 - val_accuracy: 0.5089
# Epoch 39/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1368 - accuracy: 0.5260 - val_loss: 1.1876 - val_accuracy: 0.5059
# Epoch 40/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1326 - accuracy: 0.5199 - val_loss: 1.1797 - val_accuracy: 0.5059
# Epoch 41/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1468 - accuracy: 0.5122 - val_loss: 1.2120 - val_accuracy: 0.5020
# Epoch 42/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1319 - accuracy: 0.5179 - val_loss: 1.1824 - val_accuracy: 0.5033
# Epoch 43/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1305 - accuracy: 0.5317 - val_loss: 1.2308 - val_accuracy: 0.4798
# Epoch 44/100
# 145/145 [==============================] - 3s 19ms/step - loss: 1.1223 - accuracy: 0.5267 - val_loss: 1.1681 - val_accuracy: 0.5085
# Epoch 45/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1281 - accuracy: 0.5222 - val_loss: 1.1972 - val_accuracy: 0.4885
# Epoch 46/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1374 - accuracy: 0.5179 - val_loss: 1.2136 - val_accuracy: 0.4885
# Epoch 47/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1375 - accuracy: 0.5152 - val_loss: 1.1934 - val_accuracy: 0.5054
# Epoch 48/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1264 - accuracy: 0.5252 - val_loss: 1.2023 - val_accuracy: 0.4989
# Epoch 49/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1501 - accuracy: 0.5105 - val_loss: 1.2330 - val_accuracy: 0.4781
# Epoch 50/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1370 - accuracy: 0.5204 - val_loss: 1.1588 - val_accuracy: 0.5137
# Epoch 51/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1211 - accuracy: 0.5281 - val_loss: 1.1761 - val_accuracy: 0.5106
# Epoch 52/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1275 - accuracy: 0.5242 - val_loss: 1.1707 - val_accuracy: 0.5098
# Epoch 53/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1199 - accuracy: 0.5247 - val_loss: 1.2358 - val_accuracy: 0.4659
# Epoch 54/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1229 - accuracy: 0.5265 - val_loss: 1.2042 - val_accuracy: 0.4790
# Epoch 55/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1209 - accuracy: 0.5323 - val_loss: 1.2157 - val_accuracy: 0.4881
# Epoch 56/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1173 - accuracy: 0.5253 - val_loss: 1.1694 - val_accuracy: 0.5132
# Epoch 57/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1174 - accuracy: 0.5242 - val_loss: 1.1900 - val_accuracy: 0.5020
# Epoch 58/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1167 - accuracy: 0.5245 - val_loss: 1.1892 - val_accuracy: 0.5011
# Epoch 59/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1128 - accuracy: 0.5267 - val_loss: 1.2120 - val_accuracy: 0.4950
# Epoch 60/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1130 - accuracy: 0.5289 - val_loss: 1.2080 - val_accuracy: 0.4902
# Epoch 61/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1166 - accuracy: 0.5283 - val_loss: 1.1702 - val_accuracy: 0.5098
# Epoch 62/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1150 - accuracy: 0.5255 - val_loss: 1.1819 - val_accuracy: 0.5124
# Epoch 63/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1164 - accuracy: 0.5334 - val_loss: 1.1764 - val_accuracy: 0.5015
# Epoch 64/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1104 - accuracy: 0.5338 - val_loss: 1.1777 - val_accuracy: 0.4989
# Epoch 65/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1069 - accuracy: 0.5329 - val_loss: 1.2030 - val_accuracy: 0.4902
# Epoch 66/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1080 - accuracy: 0.5295 - val_loss: 1.1806 - val_accuracy: 0.4976
# Epoch 67/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1143 - accuracy: 0.5243 - val_loss: 1.1917 - val_accuracy: 0.4894
# Epoch 68/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1092 - accuracy: 0.5267 - val_loss: 1.1761 - val_accuracy: 0.4937
# Epoch 69/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1152 - accuracy: 0.5247 - val_loss: 1.2293 - val_accuracy: 0.4629
# Epoch 70/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1131 - accuracy: 0.5274 - val_loss: 1.1902 - val_accuracy: 0.4894
# Epoch 71/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1118 - accuracy: 0.5292 - val_loss: 1.1973 - val_accuracy: 0.4885
# Epoch 72/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1075 - accuracy: 0.5355 - val_loss: 1.1768 - val_accuracy: 0.5046
# Epoch 73/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1060 - accuracy: 0.5298 - val_loss: 1.2110 - val_accuracy: 0.4963
# Epoch 74/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1080 - accuracy: 0.5291 - val_loss: 1.1876 - val_accuracy: 0.4967
# Epoch 75/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1111 - accuracy: 0.5305 - val_loss: 1.2162 - val_accuracy: 0.4837
# Epoch 76/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1087 - accuracy: 0.5314 - val_loss: 1.1961 - val_accuracy: 0.4989
# Epoch 77/100
# 145/145 [==============================] - 3s 18ms/step - loss: 1.1071 - accuracy: 0.5321 - val_loss: 1.1694 - val_accuracy: 0.4881
# Epoch 78/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1115 - accuracy: 0.5330 - val_loss: 1.1859 - val_accuracy: 0.4963
# Epoch 79/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1088 - accuracy: 0.5252 - val_loss: 1.2114 - val_accuracy: 0.4959
# Epoch 80/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1066 - accuracy: 0.5343 - val_loss: 1.1904 - val_accuracy: 0.4872
# Epoch 81/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1054 - accuracy: 0.5303 - val_loss: 1.2161 - val_accuracy: 0.4972
# Epoch 82/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1159 - accuracy: 0.5256 - val_loss: 1.1983 - val_accuracy: 0.4950
# Epoch 83/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1028 - accuracy: 0.5353 - val_loss: 1.1574 - val_accuracy: 0.5119
# Epoch 84/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1009 - accuracy: 0.5368 - val_loss: 1.1803 - val_accuracy: 0.4993
# Epoch 85/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1026 - accuracy: 0.5292 - val_loss: 1.1986 - val_accuracy: 0.4972
# Epoch 86/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.0990 - accuracy: 0.5381 - val_loss: 1.1787 - val_accuracy: 0.4976
# Epoch 87/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1036 - accuracy: 0.5333 - val_loss: 1.2379 - val_accuracy: 0.4646
# Epoch 88/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.0968 - accuracy: 0.5358 - val_loss: 1.2633 - val_accuracy: 0.4620
# Epoch 89/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1043 - accuracy: 0.5297 - val_loss: 1.2375 - val_accuracy: 0.4720
# Epoch 90/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.0988 - accuracy: 0.5322 - val_loss: 1.1931 - val_accuracy: 0.4751
# Epoch 91/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1222 - accuracy: 0.5250 - val_loss: 1.2538 - val_accuracy: 0.4586
# Epoch 92/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1044 - accuracy: 0.5332 - val_loss: 1.1943 - val_accuracy: 0.4924
# Epoch 93/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1078 - accuracy: 0.5284 - val_loss: 1.2672 - val_accuracy: 0.4573
# Epoch 94/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.0999 - accuracy: 0.5370 - val_loss: 1.1882 - val_accuracy: 0.4980
# Epoch 95/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1023 - accuracy: 0.5277 - val_loss: 1.2322 - val_accuracy: 0.4764
# Epoch 96/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.0974 - accuracy: 0.5344 - val_loss: 1.1858 - val_accuracy: 0.4837
# Epoch 97/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.0997 - accuracy: 0.5321 - val_loss: 1.2349 - val_accuracy: 0.4534
# Epoch 98/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.0989 - accuracy: 0.5335 - val_loss: 1.1835 - val_accuracy: 0.4842
# Epoch 99/100
# 145/145 [==============================] - 3s 17ms/step - loss: 1.1011 - accuracy: 0.5332 - val_loss: 1.2084 - val_accuracy: 0.4920
# Epoch 100/100
# 145/145 [==============================] - 2s 17ms/step - loss: 1.1006 - accuracy: 0.5324 - val_loss: 1.2335 - val_accuracy: 0.4725
